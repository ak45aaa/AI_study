# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()

train_input.shape
# Out:
# (60000, 28, 28)

# %%
fig, axs = plt.subplots(1, 10, figsize=(15, 1))

for i in range(10):
    axs[i].imshow(train_input[i], cmap='gray_r')
    axs[i].axis('off')
plt.show()

# %%
train_scaled = train_input.reshape(-1, 28, 28, 1) / 255.0

def model_fn(activation_fn):
    model = keras.Sequential()
    model.add(keras.layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(28, 28, 1)))
    model.add(keras.layers.MaxPooling2D(2))
    model.add(keras.layers.Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'))
    model.add(keras.layers.MaxPooling2D(2))
    
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(100, activation=activation_fn))
    model.add(keras.layers.Dropout(0.3))
    model.add(keras.layers.Dense(10, activation='softmax'))
